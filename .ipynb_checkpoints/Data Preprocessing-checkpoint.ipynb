# %%
#=====[ Import dependencies ]====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import pickle

sys.path.append('data')
sys.path.append('squat_pushupData_10to20')

#=====[ Import Data ]=====
import coords1 as cd
import coordKeys as keys
import coordKeysZ as keysZ

# %matplotlib inline

# %% [markdown]
# #Step 1: Import Data

# %%
#=====[ Option 1: Import data from text file ] =====
data = []
with open('data/squat_pushupData_10to20/squatData12.txt') as f:
    for line in f:
        data.append([float(x.replace('\r\n','')) for x in line.split(',')])

df = pd.DataFrame(data, columns=keysZ.columns)
df = df[30:]
#=====[ Option 2: Get data from python file and place in DataFrame ]=====
# data = cd.data
# df = pd.DataFrame(data,columns=keys.columns)

# %% [markdown]
# #Step 2: Isolate Individual Squats

# %%
#=====[ Extract y_coords for Neck -- provides a stable point of reference ]=====
y_coords = np.array(df.get('NeckY'))
plt.plot(y_coords,marker='+')

# %% [markdown]
# #Get Max Indices

# %%
def is_min(y_coords, height, gradient, index, epsilon, beta):
    if np.abs(y_coords[index] - height)/height < epsilon:
        for i in range(1,beta):
            if gradient[index - i] > 0 or gradient[index + i - 1] < 0:
                return False
        return True
        
def in_new_squat(y_coords, height, index, delta):
    return abs((y_coords[index] - height)/height) > delta

#=====[ Gets local maxes within accepted epsilon of global max and with max len(y_coors)/gamma maxes ]=====
#=====[ For squats: usual epsilon ~ 0.05, gamma ~ 20, delta ~ 0.5, beta ~ 1 ]=====
def get_local_mins(y_coords, epsilon=0.15, gamma=20, delta=0.5, beta=1):
    
    local_mins = []
    height = np.min(y_coords)
    gradient = np.gradient(y_coords)
    
    #=====[ Checks gradients to make sure  ]=====
    min_located = False
    for index, dy in enumerate(gradient[2:]):
        if(min_located):
            if in_new_squat(y_coords, height, index, delta):
                min_located = False       
            else:
                continue
                
        if  is_min(y_coords, height, gradient, index, epsilon, beta + 1):
            local_mins.append(index)
            min_located = True
        
    return sorted(local_mins)

# %%
#=====[ Get maxes and plot with y_coords ]=====
mins = get_local_mins(y_coords)
plt.plot(y_coords,marker='+')

for divide in mins:
    plt.axvline(divide,color='r')

# %% [markdown]
# #Separate Exercise based on max points found

# %%
squats = []

#=====[ Get points from DF between each max found -- constitutes a single squat ]=====
for index,x in enumerate(mins):
    if(index == len(mins) -1 ):
        continue
    squat = (df.loc[x:mins[index+1]-1])
    squats.append(squat.set_index([range(squat.shape[0])]))

# %% [markdown]
# #Step 3: Normalize Coordinates

# %%
def y_upper_bound(df):
    return np.min(df['HeadY'])

# %%
def y_lower_bound(df):
#     return np.median(pd.concat([df['FootRightY'],df['FootLeftY']],axis =0))
    return np.median(df['FootRightY'])

# %%
def x_zero(df):
    return np.median(df['SpineMidX'])

# %%
def z_zero(df):
    return np.median(np.concatenate([df.get('FootLeftZ'),df.get('FootRightZ')],axis=0))

# %%
def scaling_factor(df):
    return np.abs(y_upper_bound(df) - y_lower_bound(df))

# %%
def normalize(squats, z_coords=False):
    
    #=====[ Normalizing constants for the entire set of exercises ]=====
    y_head = y_upper_bound(df)
    scale = scaling_factor(df)
    x_midpoint = x_zero(df)
    if(z_coords):
        z_midpoint = z_zero(df)

    for indice, squat in enumerate(squats):
        
        #=====[ Even columns are x-coordinates, odd columns are y-coordinates -- normalize respectively ]=====
        if(not z_coords):
            for index, col in enumerate(squat.columns):
                if (index % 2) == 1:
                    squat[col] = squat[col].apply((lambda y: ((y - y_head)/scale)))
                else:
                    squat[col] = squat[col].apply((lambda x: ((x - x_midpoint)/scale)))
        else:
            for index, col in enumerate(squat.columns):
                if index % 3 == 2:
                    squat[col] = squat[col].apply((lambda z: ((z - z_midpoint)/scale)))
                elif index % 3 == 1:
                    squat[col] = squat[col].apply((lambda y: ((y - y_head)/scale)))
                else:
                    squat[col] = squat[col].apply(lambda x: ((x - x_midpoint)/scale))
                    
        if indice > 0:
            break

# %%
squats[1]
# Out:
#     SpineBaseX  SpineBaseY  SpineBaseZ   SpineMidX   SpineMidY  SpineMidZ  \
# 0   266.066925  244.887619    2.560747  266.056915  211.326492   2.422725
# 1   266.409210  237.339630    2.559443  267.134460  202.237503   2.422367
# 2   266.261871  234.788971    2.559849  266.996857  199.555664   2.423669
# 3   266.322266  229.993347    2.559266  267.342560  193.918945   2.426435
# 4   266.325470  225.547180    2.555493  266.920135  188.256592   2.426419
# 5   267.431641  220.328979    2.555164  267.806763  183.448944   2.428927
# 6   267.339508  216.266907    2.551466  267.573120  177.091965   2.428063
# 7   267.433716  212.223557    2.548240  267.626160  172.903763   2.428916
# 8   267.571625  207.103928    2.539201  268.381256  165.617477   2.424433
# 9   267.483612  203.642136    2.535265  268.147858  164.784302   2.426555
# 10  266.902802  192.240051    2.512407  267.775665  149.460327   2.417106
# 11  267.058472  189.940170    2.507958  267.794861  145.822632   2.416909
# 12  266.733032  184.407593    2.497100  267.750610  144.959976   2.415573
# 13  266.934662  182.230698    2.491430  267.870544  141.278610   2.411559
# 14  267.322327  179.189850    2.481594  267.910492  138.694901   2.408490
# 15  266.934784  177.609924    2.478191  267.722229  137.326752   2.406755
# 16  266.642029  176.676819    2.475002  267.581543  136.379211   2.405132
# 17  266.237000  175.259857    2.428801  267.501953  135.255615   2.392307
# 18  267.804565  169.279526    2.392760  268.293976  124.472824   2.362243
# 19  267.812653  169.445038    2.391521  268.302002  124.505051   2.362002
# 20  267.815125  169.539551    2.390460  268.304199  124.523170   2.361684
# 21  267.874329  169.600067    2.388944  268.330780  124.532860   2.361084
# 22  268.008148  169.692780    2.383292  268.427795  124.546700   2.358746
# 23  268.032806  169.641998    2.379889  268.451935  124.507454   2.357210
# 24  268.042236  169.655884    2.378317  268.464661  124.495361   2.356136
# 25  268.040527  169.697601    2.376615  268.473602  124.494049   2.355096
# 26  268.056824  169.698715    2.375807  268.491516  124.489098   2.354462
# 27  268.056976  169.679047    2.375178  268.494202  124.464134   2.353866
# 28  268.037842  169.669769    2.374824  268.489502  124.456772   2.353555
# 29  268.035858  169.665451    2.374756  268.488983  124.448486   2.353357
# 30  268.032562  169.703735    2.374856  268.479797  124.475853   2.353269
# 31  267.979034  169.807419    2.375581  268.456238  124.530571   2.353327
# 32  267.790558  170.227356    2.379655  268.396362  124.731842   2.354070
# 33  267.774780  171.016296    2.385858  268.343964  125.301277   2.355837
# 34  267.826569  172.550705    2.395744  268.258850  127.707329   2.359039
# 35  267.489136  174.849213    2.406388  268.111389  130.678513   2.362779
# 36  267.367310  177.764618    2.416075  267.996765  133.939362   2.366271
# 0        2.246128   288.495178   146.834793     2.247334
# 1        2.259390   287.295685   141.702271     2.246900
# 2        2.259203   289.194489   136.901337     2.253700
# 3        2.259680   279.999969   128.504517     2.177100
# 4        2.263485   280.365906   124.200874     2.188909
# 5        2.275889   279.667511   124.587807     2.192833
# 6        2.284660   280.669067   113.019798     2.213444
# 7        2.278166   281.502686   107.507805     2.232667
# 8        2.307530   280.917297    96.088112     2.227000
# 9        2.323472   281.167633    90.339493     2.235167
# 10       2.318863   281.803284    82.012680     2.263300
# 11       2.339295   281.251526    73.507645     2.251417
# 12       2.338241   281.287933    69.226974     2.260214
# 13       2.323089   281.501587    69.004822     2.265600
# 14       2.340817   281.885468    60.840698     2.276647
# 15       2.334835   282.670013    62.005295     2.303000
# 16       2.350687   281.000061    58.002350     2.266286
# 17       2.370221   281.334259    54.247208     2.270917
# 18       2.359145   281.345062    56.137466     2.274475
# 19       2.339976   281.500732    51.497894     2.269125
# 20       2.338662   281.576660    60.580826     2.288286
# 21       2.336665   281.111084    54.999191     2.269778
# 22       2.330942   281.600250    51.600861     2.260800
# 23       2.327028   282.009674    60.349625     2.292444
# 24       2.333666   282.257843    61.016708     2.296750
# 25       2.347105   281.535583    54.946121     2.270334
# 26       2.341606   281.366760    57.748367     2.270727
# 27       2.354825   281.462341    51.921799     2.264923
# 28       2.330068   281.288513    58.009888     2.272857
# 29       2.336606   281.523682    55.351944     2.273029
# 30       2.323375   281.666199    49.334427     2.258667
# 31       2.322688   284.790619    51.999420     2.271500
# 32       2.316955   281.333282    53.000641     2.257334
# 33       2.314025   281.000061    52.251205     2.243250
# 34       2.297271   280.500427    52.665833     2.235333
# 35       2.306718   280.818695    59.727386     2.240182
# 36       2.327330   280.250519    65.001526     2.233333
# 37       2.299338   280.334869    65.999420     2.227000
# 38       2.328422   280.000092    75.225769     2.224667
# 39       2.301955   280.538849    75.924820     2.213538
# 40       2.301018   280.499512    81.505211     2.207600
# 41       2.304572   279.917297    92.010063     2.206000
# 42       2.285626   279.753235    95.243484     2.191188
# 43       2.284677   279.335144   105.122345     2.183444
# 44       2.276725   279.250763   109.761482     2.174125
# 45       2.260266   280.364410   112.458366     2.179727
#
# [46 rows x 75 columns]

# %%
#=====[ Normalize squats: ensure z_coords is set to true if extracting 3-d coordinates ]=====
normalize(squats,z_coords = True)

# %%
#=====[ Visual comparison between reps ]=====
for index, squat in enumerate(squats):
    plt.plot(squat.get('HeadY'),label="Rep " + str(index + 1))
    if index > 0:
        break
plt.legend()

# %%
#=====[ Save squats in pickle file if desired ]=====
pickle.dump(squats,open('squats10.p','wb'))

# %% [markdown]
# #Visualize Scaled Body

# %%
def plotBody(df,frame,z_coords=False):
    coords = np.array(df.loc[df.index[0] + frame])
    if not z_coords:
        xs = [coords[i] for i in range(0,coords.size) if i % 2 == 0]
        ys = [-1*coords[i] for i in range(0,coords.size) if i % 2 == 1]
    else:
    plt.plot(xs,ys,linestyle='None',marker='o')
# Out:
#   File "<ipython-input-110-8f654bb9ff0d>", line 7
#     plt.plot(xs,ys,linestyle='None',marker='o')
#       ^
# IndentationError: expected an indented block

# %%
plotBody(squats[1],20)

# %%
new_df = squat.set_index([range(squat.shape[0])])
