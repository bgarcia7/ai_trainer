# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ai_trainer import Personal_Trainer
import squat_separation as ss
import sys
import pickle
import os
import random as rnd

sys.path.append('data')


# %matplotlib inline

# %% [markdown]
# #Step 1: Instantiate our personal trainer and load preprocessed data

# %%
pt = Personal_Trainer('NeckY')
pt.load_advanced_squats('multipleClass.p')

# %% [markdown]
# #Step 2: Extract features

# %%
plt.clf()
for squat in pt.get_squats():
    plt.plot(-squat['NeckY'])

# %%
X, Y, file_names = pt.extract_advanced_features()
# Out:
# setting an array element with a sequence. head_alignment

# %% [markdown]
# #Step 3: Classification

# %% [markdown]
# ##Scale features and define testing functions

# %%
from sklearn import preprocessing
from sklearn import cross_validation
from sklearn import metrics
import random

def predict_labels(X, y, X_test, clf_class, **kwargs):
    clf = clf_class(**kwargs)
    clf.fit(X ,y)
    return clf.predict(X_test)

def stratified_cv(X, y, clf_class, shuffle=True, n_folds=10, **kwargs):
    stratified_k_fold = cross_validation.StratifiedKFold(y, n_folds=n_folds, shuffle=shuffle)
    y_pred = y.copy()
    for i, j in stratified_k_fold:
        X_train, X_test = X[i], X[j]
        y_train = y[i]
        clf = clf_class(**kwargs)
        clf.fit(X_train,y_train)
        y_pred[j] = clf.predict(X_test)
    return y_pred

def rnd_prediction(training_data, labels, file_names, clf_class, toIgnore=None, num_iters=10, **kwargs):
    
    #=====[ Instantiate our personal trainer for feature extraction ]=====
    accuracy = 0

    #=====[ Randomly leave out one of the files and test on it num_iter times ]======
    for _ in range(num_iters):
        squats = []

        if toIgnore == None:
            print "is this an issue?"
            toIgnore = random.sample(file_names,1)[0]

    
        X = [x for index, x in enumerate(training_data) if file_names[index] != toIgnore]
        Y = [y for index, y in enumerate(labels) if file_names[index] != toIgnore]
        
        X_test = [x for index, x in enumerate(training_data) if file_names[index] == toIgnore]
        y_test = [y for index, y in enumerate(labels) if file_names[index] == toIgnore]
        
        local_accuracy = metrics.accuracy_score(y_test, predict_labels(X, Y, X_test, clf_class, **kwargs))
        accuracy += local_accuracy
        
        print(toIgnore, local_accuracy)


    print
    return accuracy/num_iters

# %% [markdown]
# ##Test Various Classifiers

# %%
from sklearn import ensemble
from sklearn import svm
from sklearn import neighbors
from sklearn import linear_model

# print('Logistic Regression:           {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, linear_model.LogisticRegression))))
# print('Support vector machine(SVM):   {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, svm.SVC))))
# print('Random Forest Classifier:      {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, ensemble.RandomForestClassifier))))

# %% [markdown]
# ##Build classifier for each feature set and test against individuals that have no input into the training set

# %%
def classify(feature_key, data_dir):
    print('Logistic Regression:           {:.2f}'.format(rnd_prediction(feature_key, data_dir, linear_model.LogisticRegression)))
    print('Support vector machine(SVM):   {:.2f}'.format(rnd_prediction(feature_key, data_dir, svm.SVC)))
    print('Random Forest Classifier:      {:.2f}'.format(rnd_prediction(feature_key, data_dir, ensemble.RandomForestClassifier)))

# %%
for key in X:
    x = X[key]
    y = Y[key]
    print '\n\n', key, '\n#############################'
    try:
        print('Logistic Regression:           {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(x, y, linear_model.LogisticRegression))))
        print('Support vector machine(SVM):   {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(x, y, svm.SVC))))
        print('Random Forest Classifier:      {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(x, y, ensemble.RandomForestClassifier))))
    except Exception as e:
        print e
# Out:
# bend_hips_knees
# #############################
# Logistic Regression:           0.94
# Support vector machine(SVM):   0.91
# Random Forest Classifier:      0.94
#
#
# stance_alignment
# #############################
# This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#
# squat_depth
# #############################
# Logistic Regression:           0.90
# Support vector machine(SVM):   0.90
# Random Forest Classifier:      0.90
#
#
# knees_over_toes
# #############################
# Logistic Regression:           0.78
# Support vector machine(SVM):   0.85
# Random Forest Classifier:      0.81

# %%
for key in X:
    x = X[key]
    y = Y[key]
    print '\n\n', key, '\n#############################'
    rnd_prediction(x, y, file_names, linear_model.LogisticRegression)
    rnd_prediction(x, y, file_names, svm.SVC)
    rnd_prediction(x, y, file_names, ensemble.RandomForestClassifier)
# Out:
# bend_hips_knees
# #############################
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
# ('squats11.p', 1.0)
#
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
# ('squats13.p', 0.90000000000000002)
#
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
# ('squats14.p', 0.0)
#
#
#
# stance_alignment
# #############################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-845452c6c0ce> in <module>()
#       3     y = Y[key]
#       4     print '\n\n', key, '\n#############################'
# ----> 5     rnd_prediction(x, y, file_names, linear_model.LogisticRegression)
#       6     rnd_prediction(x, y, file_names, svm.SVC)
#       7     rnd_prediction(x, y, file_names, ensemble.RandomForestClassifier)
#
# <ipython-input-11-f0edb276fa88> in rnd_prediction(training_data, labels, file_names, clf_class, toIgnore, num_iters, **kwargs)
#      39         y_test = [y for index, y in enumerate(labels) if file_names[index] == toIgnore]
#      40
# ---> 41         local_accuracy = metrics.accuracy_score(y_test, predict_labels(X, Y, X_test, clf_class, **kwargs))
#      42         accuracy += local_accuracy
#      43
#
# <ipython-input-11-f0edb276fa88> in predict_labels(X, y, X_test, clf_class, **kwargs)
#       6 def predict_labels(X, y, X_test, clf_class, **kwargs):
#       7     clf = clf_class(**kwargs)
# ----> 8     clf.fit(X ,y)
#       9     return clf.predict(X_test)
#      10
#
# /Library/Python/2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y)
#    1034                 X, y, self.C, self.fit_intercept, self.intercept_scaling,
#    1035                 self.class_weight, self.penalty, self.dual, self.verbose,
# -> 1036                 self.max_iter, self.tol
#    1037                 )
#    1038             return self
#
# /Library/Python/2.7/site-packages/sklearn/svm/base.pyc in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon)
#     807             raise ValueError("This solver needs samples of at least 2 classes"
#     808                              " in the data, but the data contains only one"
# --> 809                              " class: %r" % classes_[0])
#     810
#     811         class_weight_ = compute_class_weight(class_weight, classes_, y)
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
