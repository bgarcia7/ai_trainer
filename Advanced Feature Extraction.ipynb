# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ai_trainer import Personal_Trainer
import squat_separation as ss
import sys
import os
import featurizer as fz

sys.path.append('data/squat_pushupData_10to20')

# %matplotlib inline

# %%
pt = Personal_Trainer('NeckY')
pt.load_squats(os.path.join('data/data_sets/','170_squats_full.p'))

# %%
squats = pt.get_squats()
squat = squats[0]

# %%
a = fz.extract_stance_shoulder_width(squat[0],pt.key,pt.keys_to_indices)
